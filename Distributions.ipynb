# %%
import gzip
import csv

# %%
betw = []
with gzip.open("yeast/raw_betwe_centrality.txt.gz") as f:
    rd = csv.reader(f,delimiter="\t")
    for g,bl in rd:
        betw.append(float(g))

# %%
h_betw = []
with gzip.open("human/raw_betwe_centrality.txt.gz") as f:
    rd = csv.reader(f,delimiter="\t")
    for g,bl in rd:
        h_betw.append(float(g))

# %%
close = []
with gzip.open("yeast/raw_close_centrality.txt.gz") as f:
    rd = csv.reader(f,delimiter="\t")
    for g,bl in rd:
        close.append(float(g))

# %%
h_close = []
with gzip.open("human/raw_close_centrality.txt.gz") as f:
    rd = csv.reader(f,delimiter="\t")
    for g,bl in rd:
        h_close.append(float(g))

# %%
degree = []
with gzip.open("yeast/raw_degree_centrality.txt.gz") as f:
    rd = csv.reader(f,delimiter="\t")
    for g,bl in rd:
        degree.append(float(g))

# %%
h_degree = []
with gzip.open("human/raw_degree_centrality.txt.gz") as f:
    rd = csv.reader(f,delimiter="\t")
    for g,bl in rd:
        h_degree.append(float(g))

# %%
rand = []
with gzip.open("yeast/raw_random_walking.txt.gz") as f:
    rd = csv.reader(f,delimiter="\t")
    for g,bl in rd:
        rand.append(float(g))

# %%
genes = []
with gzip.open("yeast/raw_nodelist.txt.gz") as f:
    rd = csv.reader(f,delimiter="\t")
    for g,bl in rd:
        genes.append(float(g))

# %%
h_genes = []
with gzip.open("human/raw_nodelist.txt.gz") as f:
    rd = csv.reader(f,delimiter="\t")
    for g,bl in rd:
        h_genes.append(float(g))

# %%
eigen = []
with gzip.open("yeast/raw_eigen_centrality.txt.gz") as f:
    rd = csv.reader(f,delimiter="\t")
    for g,bl in rd:
        eigen.append(float(g))

# %%
page = []
with gzip.open("yeast/raw_pagerank.txt.gz") as f:
    rd = csv.reader(f,delimiter="\t")
    for g,bl in rd:
        page.append(float(g))

# %%
sec = []
with gzip.open("yeast/raw_2nd_degree_neighbours.txt.gz") as f:
    rd = csv.reader(f,delimiter="\t")
    for g,bl in rd:
        sec.append(float(g))

# %%
comc = []
with gzip.open("yeast/raw_commun_centrality.txt.gz") as f:
    rd = csv.reader(f,delimiter="\t")
    for g,bl in rd:
        comc.append(float(g))

# %%
ecc = []
with gzip.open("yeast/raw_eccentricity.txt.gz") as f:
    rd = csv.reader(f,delimiter="\t")
    for g,bl in rd:
        ecc.append(float(g))

# %%
import matplotlib.pyplot as plt
import numpy
# %matplotlib inline

# %%
plt.scatter(close,degree)
plt.show()

# %%
plt.scatter(numpy.log(close),numpy.log(degree))
plt.show()

# %%
plt.scatter(h_close,h_degree)
plt.show()

# %%
plt.scatter(numpy.log(h_close),numpy.log(h_degree))
plt.show()

# %%
for n,i in enumerate(h_close):
    if i > 0.6:
        print h_genes[n]
#7316 is ubiquitin - a natural center, it seems. center of the earth.
# Out:
# 7316.0

# %%
plt.scatter(close,betw)
plt.show()

# %%
plt.scatter(numpy.log(close),numpy.log(betw))
plt.show()
# Out:
# -c:1: RuntimeWarning: divide by zero encountered in log

# %%
plt.scatter(degree,betw)
plt.show()

# %%
plt.scatter(numpy.log(degree),numpy.log(betw))
plt.show()

# %%
plt.scatter(degree,eigen)
plt.show()

# %%
plt.scatter(degree,rand)
plt.show()

# %%
plt.scatter(betw,eigen)
plt.show()

# %%
plt.scatter(betw,rand)
plt.show()

# %%
plt.scatter(close,eigen)
plt.show()

# %%
plt.scatter(close,page)
plt.show()

# %%
plt.scatter(close,sec)
plt.show()

# %%
plt.scatter(close,comc)
plt.show()

# %%
plt.scatter(sec,comc)
plt.show()

# %%
plt.scatter(sec,ecc)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import pylab

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(close,betw, degree)
plt.show()

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(close,betw,eigen)
plt.show()

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(page,close,eigen)
plt.show()

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(eigen,close,sec)
plt.show()

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(comc,close,sec)
plt.show()

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(close,comc,sec)
plt.show()

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(numpy.log(close),numpy.log(comc),numpy.log(sec))
plt.show()

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(ecc,comc,sec)
ax.set_xlabel('Eccentricity')
ax.set_ylabel('Comm. Centrality')
ax.set_zlabel('2nd Degree Neighbours')
plt.show()

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(numpy.log(ecc),numpy.log(comc),numpy.log(sec))
ax.set_xlabel('Eccentricity')
ax.set_ylabel('Comm. Centrality')
ax.set_zlabel('2nd Degree Neighbours')
plt.show()

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(sec,comc,ecc)
ax.set_xlabel('2nd Degree Neighbours')
ax.set_ylabel('Comm. Centrality')
ax.set_zlabel('Eccentricity')
plt.show()

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(ecc,eigen,sec)
plt.show()

# %%
print "pagerank:"
for n,i in enumerate(page):
    if i > 0.01:
        print genes[n]
#850620: Ubiquitin; 852755: NAB2 (repress/activate transcription)
print "Eigen:"
for n,i in enumerate(eigen):
    if i > 0.1:
        print genes[n]

print "Betweenness:"
for n,i in enumerate(betw):
    if i > 0.1:
        print genes[n]
# Out:
# pagerank:
# 850620.0
# 852755.0
# Eigen:
# 850554.0
# 850647.0
# 850620.0
# 850320.0
# 856895.0
# 852755.0
# 852122.0
# 856351.0
# 855466.0
# Betweenness:
# 850620.0
# 852755.0

# %%
for n, i in enumerate(genes):
    if i == 856563.0:
        print betw[n]
        print page[n]
        print eigen[n]
        print close[n]
# Out:
# 0.000196490007604
# 0.000229750813125
# 0.0102662243778
# 0.431286658252

# %%
yGPS = []
with gzip.open('yeast/ML_GPS.txt.gz') as f:
    for r in f:
        yGPS.append(float(str.strip(r)))

# %%
n,b,p = plt.hist(yGPS,40)
plt.show()

# %%
ysqGPS = []
with gzip.open('yeast/ML_GPS.txt.gz') as f:
    for r in f:
        ysqGPS.append(float(str.strip(r)))

# %%
n,b,p = plt.hist(ysqGPS,40)
plt.show()
